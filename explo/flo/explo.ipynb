# %%
import pandas as pd
from datetime import datetime as dt

# %%
start_date = dt(2020, 11, 8)
end_date = dt(2020, 11, 9)

# %%
pd.date_range(start_date, end_date, freq='15T').to_pydatetime()[1].strftime("%Y%m%d%H%M%S")
# Out:
# '20201108001500'

# %%
"abc.zip".replace('.zip', '')
# Out:
# 'abc'

# %%
events = pd.read_csv("../../data/raw/20230101000000.translation.export.csv", delimiter="\t", header=None)
print(events.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       332 non-null    int64
#  1   1       332 non-null    int64
#  2   2       332 non-null    int64
#  3   3       332 non-null    int64
#  4   4       332 non-null    float64
#  5   5       280 non-null    object
#  6   6       280 non-null    object
#  7   7       174 non-null    object
#  8   8       4 non-null      object
#  9   9       0 non-null      float64
#  10  10      3 non-null      object
#  11  11      2 non-null      object
#  12  12      139 non-null    object
#  13  13      4 non-null      object
#  14  14      0 non-null      float64
#  15  15      198 non-null    object
#  16  16      198 non-null    object
#  17  17      116 non-null    object
#  18  18      3 non-null      object
#  19  19      0 non-null      float64
#  20  20      1 non-null      object
#  21  21      1 non-null      object
#  22  22      84 non-null     object
#  23  23      2 non-null      object
#  24  24      0 non-null      float64
#  25  25      332 non-null    int64
#  26  26      332 non-null    int64
#  27  27      332 non-null    int64
#  28  28      332 non-null    int64
#  29  29      332 non-null    int64
#  30  30      332 non-null    float64
#  31  31      332 non-null    int64
#  32  32      332 non-null    int64
#  33  33      332 non-null    int64
#  34  34      332 non-null    float64
#  35  35      332 non-null    int64
#  36  36      264 non-null    object
#  37  37      264 non-null    object
#  38  38      264 non-null    object
#  39  39      140 non-null    object
#  40  40      264 non-null    float64
#  41  41      264 non-null    float64
#  42  42      264 non-null    object
#  43  43      332 non-null    int64
#  44  44      189 non-null    object
#  45  45      189 non-null    object
#  46  46      189 non-null    object
#  47  47      96 non-null     object
#  48  48      189 non-null    float64
#  49  49      189 non-null    float64
#  50  50      189 non-null    object
#  51  51      332 non-null    int64
#  52  52      311 non-null    object
#  53  53      311 non-null    object
#  54  54      311 non-null    object
#  55  55      166 non-null    object
#  56  56      311 non-null    float64
#  57  57      311 non-null    float64
#  58  58      311 non-null    object
#  59  59      332 non-null    int64
#  60  60      332 non-null    object
# dtypes: float64(13), int64(16), object(32)
# memory usage: 158.3+ KB
# None

# %%
cols = ['GlobalEventID','Day','MonthYear','Year','FractionDate','Actor1Code','Actor1Name','Actor1CountryCode','Actor1KnownGroupCode','Actor1EthnicCode','Actor1Religion1Code','Actor1Religion2Code','Actor1Type1Code','Actor1Type2Code','Actor1Type3Code','Actor2Code','Actor2Name','Actor2CountryCode','Actor2KnownGroupCode','Actor2EthnicCode','Actor2Religion1Code','Actor2Religion2Code','Actor2Type1Code','Actor2Type2Code','Actor2Type3Code','IsRootEvent','EventCode','EventBaseCode','EventRootCode','QuadClass','GoldsteinScale','NumMentions','NumSources','NumArticles','AvgTone','Actor1Geo_Type','Actor1Geo_FullName','Actor1Geo_CountryCode','Actor1Geo_ADM1Code','Actor1Geo_ADM2Code','Actor1Geo_Lat','Actor1Geo_Long','Actor1Geo_FeatureID','Actor2Geo_Type','Actor2Geo_FullName','Actor2Geo_CountryCode','Actor2Geo_ADM1Code','Actor2Geo_ADM2Code','Actor2Geo_Lat','Actor2Geo_Long','Actor2Geo_FeatureID','ActionGeo_Type','ActionGeo_FullName','ActionGeo_CountryCode','ActionGeo_ADM1Code','ActionGeo_ADM2Code','ActionGeo_Lat','ActionGeo_Long','ActionGeo_FeatureID','DATEADDED','SOURCEURL']

events.columns = cols
events
# Out:
#      GlobalEventID       Day  MonthYear  Year  FractionDate Actor1Code  \
# 0       1078327865  20220101     202201  2022     2022.0027        MIL
# 1       1078327866  20220101     202201  2022     2022.0027        PRK
# 2       1078327867  20220101     202201  2022     2022.0027        RUS
# 3       1078327868  20230101     202301  2023     2023.0027        NaN
# 4       1078327869  20230101     202301  2023     2023.0027        NaN
# ..             ...       ...        ...   ...           ...        ...
# 327     1078328192  20230101     202301  2023     2023.0027        VAT
# 328     1078328193  20230101     202301  2023     2023.0027        VAT
# 329     1078328194  20230101     202301  2023     2023.0027        VAT
# 330     1078328195  20230101     202301  2023     2023.0027        VEN
# 331     1078328196  20230101     202301  2023     2023.0027        VEN
#
#       Actor1Name Actor1CountryCode Actor1KnownGroupCode  Actor1EthnicCode  \
# 0       MILITARY               NaN                  NaN               NaN
# 1    NORTH KOREA               PRK                  NaN               NaN
# 2        RUSSIAN               RUS                  NaN               NaN
# 3            NaN               NaN                  NaN               NaN
# 4            NaN               NaN                  NaN               NaN
# ..           ...               ...                  ...               ...
# 327      VATICAN               VAT                  NaN               NaN
# 328      VATICAN               VAT                  NaN               NaN
# 329      VATICAN               VAT                  NaN               NaN
# 330    VENEZUELA               VEN                  NaN               NaN
# 331    VENEZUELA               VEN                  NaN               NaN
#
#      ... ActionGeo_Type                     ActionGeo_FullName  \
# 0    ...              1                                 Russia
# 1    ...              4  Pyongyang, P'yongyang-si, North Korea
# 2    ...              4       Kiev, Ukraine (general), Ukraine
# 3    ...              1                              Argentina
# 4    ...              1                              Argentina
# ..   ...            ...                                    ...
# 327  ...              4                Munich, Bayern, Germany
# 328  ...              1                                   Iraq
# 329  ...              2                New York, United States
# 330  ...              4     Brasilia, Distrito Federal, Brazil
# 331  ...              1                              Venezuela
#
#     ActionGeo_CountryCode ActionGeo_ADM1Code  ActionGeo_ADM2Code  \
# 0                      RS                 RS                 NaN
# 1                      KN               KN12               39681
# 2                      UP               UP00               28554
# 3                      AR                 AR                 NaN
# 4                      AR                 AR                 NaN
# ..                    ...                ...                 ...
# 327                    GM               GM02               16532
# 328                    IZ                 IZ                 NaN
# 329                    US               USNY                 NaN
# 330                    BR               BR07               40202
# 331                    VE                 VE                 NaN
#
#     ActionGeo_Lat ActionGeo_Long ActionGeo_FeatureID       DATEADDED  \
# 0         60.0000       100.0000                  RS  20230101000000
# 1         39.0194       125.7550             -183459  20230101000000
# 2         50.4333        30.5167            -1044367  20230101000000
# 3        -34.0000       -64.0000                  AR  20230101000000
# 4        -34.0000       -64.0000                  AR  20230101000000
# ..            ...            ...                 ...             ...
# 327       48.1500        11.5833            -1829149  20230101000000
# 328       33.0000        44.0000                  IZ  20230101000000
# 329       42.1497       -74.9384                  NY  20230101000000
# 330      -15.7833       -47.9167             -631243  20230101000000
# 331        8.0000       -66.0000                  VE  20230101000000
#
#                                              SOURCEURL
# 0    https://tass.ru/mezhdunarodnaya-panorama/16729839
# 1       https://www.fnnews.com/news/202301010518250550
# 2    https://www.novinky.cz/clanek/valka-na-ukrajin...
# 3    https://www.pagina12.com.ar/512400-alberto-fer...
# 4    https://www.pagina12.com.ar/512400-alberto-fer...
# ..                                                 ...
# 327  https://wtop.com/news/2022/12/el-rottweiler-de...
# 328  https://wtop.com/news/2022/12/el-rottweiler-de...
# 329  https://wtop.com/news/2022/12/el-rottweiler-de...
# 330  https://www.bahianoticias.com.br:443/folha/not...
# 331  https://www.bahianoticias.com.br:443/folha/not...
#
# [332 rows x 61 columns]

# %%
cols.index("Actor2Name")
MATCH (event:Event {GlobalEventID : "1078327865"})
MATCH (ressource:Ressource {OriginalID : "OriginalID: https://tass.ru/mezhdunarodnaya-panorama/16729839"})
MERGE (ressource)-[:MENTIONS]->(event)
RETURN event, ressource
# Out:
# 16

# %%
mentions = pd.read_csv("../../data/raw/20230101000000.translation.mentions.csv", delimiter="\t", header=None)
mentions
# Out:
#              0               1               2   3                     4   \
# 0    1078327865  20230101000000  20230101000000   1               tass.ru
# 1    1078327865  20230101000000  20230101000000   1               tass.ru
# 2    1078327866  20230101000000  20230101000000   1          etoday.co.kr
# 3    1078327866  20230101000000  20230101000000   1            fnnews.com
# 4    1078327867  20230101000000  20230101000000   1            novinky.cz
# ..          ...             ...             ...  ..                   ...
# 361  1078328192  20230101000000  20230101000000   1              wtop.com
# 362  1078328193  20230101000000  20230101000000   1              wtop.com
# 363  1078328194  20230101000000  20230101000000   1              wtop.com
# 364  1078328195  20230101000000  20230101000000   1  bahianoticias.com.br
# 365  1078328196  20230101000000  20230101000000   1  bahianoticias.com.br
#
#                                                     5   6     7     8     9   \
# 0    https://tass.ru/mezhdunarodnaya-panorama/16729839   9  2966    -1  3002
# 1                https://tass.ru/armiya-i-opk/16729333   3   348    -1   384
# 2           https://www.etoday.co.kr/news/view/2208178   5  1610    -1  1708
# 3       https://www.fnnews.com/news/202301010518250550   7  2807    -1  2900
# 4    https://www.novinky.cz/clanek/valka-na-ukrajin...   5   639   625   611
# ..                                                 ...  ..   ...   ...   ...
# 361  https://wtop.com/news/2022/12/el-rottweiler-de...  20  8389  8407  8419
# 362  https://wtop.com/news/2022/12/el-rottweiler-de...  20  8389  8407  8419
# 363  https://wtop.com/news/2022/12/el-rottweiler-de...  10  4111  4129  4119
# 364  https://www.bahianoticias.com.br:443/folha/not...  10  3285  3392  3343
# 365  https://www.bahianoticias.com.br:443/folha/not...  10  3285  3392  3343
#
#      10   11     12        13  \
# 0     1  100   4492  0.953678
# 1     1  100   1477  2.857143
# 2     1  100   2618  0.000000
# 3     1  100   3062 -3.036876
# 4     1  100   1964  0.613497
# ..   ..  ...    ...       ...
# 361   0   20  13874 -3.765511
# 362   1   80  13874 -3.765511
# 363   0   40  13874 -3.765511
# 364   1   80   4252  0.928793
# 365   0   20   4252  0.928793
#
#                                                     14  15
# 0    srclc:rus;eng:Moses 2.1.1 / MosesCore Europarl... NaN
# 1    srclc:rus;eng:Moses 2.1.1 / MosesCore Europarl... NaN
# 2                             srclc:kor;eng:GT-KOR 1.0 NaN
# 3                             srclc:kor;eng:GT-KOR 1.0 NaN
# 4    srclc:ces;eng:Moses 2.1.1 / MosesCore Europarl... NaN
# ..                                                 ...  ..
# 361  srclc:spa;eng:Moses 2.1.1 / MosesCore Europarl... NaN
# 362  srclc:spa;eng:Moses 2.1.1 / MosesCore Europarl... NaN
# 363  srclc:spa;eng:Moses 2.1.1 / MosesCore Europarl... NaN
# 364                           srclc:por;eng:GT-POR 1.0 NaN
# 365                           srclc:por;eng:GT-POR 1.0 NaN
#
# [366 rows x 16 columns]

# %%
header_mentions = ['GlobalEventID',
'EventTimeDate',
'MentionTimeDate',
'MentionType',
'MentionSourceName',
'MentionIdentifier',
'SentenceID',
'Actor1CharOffset',
'Actor2CharOffset',
'ActionCharOffset',
'InRawText',
'Confidence',
'MentionDocLen',
'MentionDocTone',
'MentionDocTranslationInfo',
'Extras']

mentions.columns = header_mentions
mentions
# Out:
#      GlobalEventID   EventTimeDate  MentionTimeDate  MentionType  \
# 0       1078327865  20230101000000   20230101000000            1
# 1       1078327865  20230101000000   20230101000000            1
# 2       1078327866  20230101000000   20230101000000            1
# 3       1078327866  20230101000000   20230101000000            1
# 4       1078327867  20230101000000   20230101000000            1
# ..             ...             ...              ...          ...
# 361     1078328192  20230101000000   20230101000000            1
# 362     1078328193  20230101000000   20230101000000            1
# 363     1078328194  20230101000000   20230101000000            1
# 364     1078328195  20230101000000   20230101000000            1
# 365     1078328196  20230101000000   20230101000000            1
#
#         MentionSourceName                                  MentionIdentifier  \
# 0                 tass.ru  https://tass.ru/mezhdunarodnaya-panorama/16729839
# 1                 tass.ru              https://tass.ru/armiya-i-opk/16729333
# 2            etoday.co.kr         https://www.etoday.co.kr/news/view/2208178
# 3              fnnews.com     https://www.fnnews.com/news/202301010518250550
# 4              novinky.cz  https://www.novinky.cz/clanek/valka-na-ukrajin...
# ..                    ...                                                ...
# 361              wtop.com  https://wtop.com/news/2022/12/el-rottweiler-de...
# 362              wtop.com  https://wtop.com/news/2022/12/el-rottweiler-de...
# 363              wtop.com  https://wtop.com/news/2022/12/el-rottweiler-de...
# 364  bahianoticias.com.br  https://www.bahianoticias.com.br:443/folha/not...
# 365  bahianoticias.com.br  https://www.bahianoticias.com.br:443/folha/not...
#
#      SentenceID  Actor1CharOffset  Actor2CharOffset  ActionCharOffset  \
# 0             9              2966                -1              3002
# 1             3               348                -1               384
# 2             5              1610                -1              1708
# 3             7              2807                -1              2900
# 4             5               639               625               611
# ..          ...               ...               ...               ...
# 361          20              8389              8407              8419
# 362          20              8389              8407              8419
# 363          10              4111              4129              4119
# 364          10              3285              3392              3343
# 365          10              3285              3392              3343
#
#      InRawText  Confidence  MentionDocLen  MentionDocTone  \
# 0            1         100           4492        0.953678
# 1            1         100           1477        2.857143
# 2            1         100           2618        0.000000
# 3            1         100           3062       -3.036876
# 4            1         100           1964        0.613497
# ..         ...         ...            ...             ...
# 361          0          20          13874       -3.765511
# 362          1          80          13874       -3.765511
# 363          0          40          13874       -3.765511
# 364          1          80           4252        0.928793
# 365          0          20           4252        0.928793
#
#                              MentionDocTranslationInfo  Extras
# 0    srclc:rus;eng:Moses 2.1.1 / MosesCore Europarl...     NaN
# 1    srclc:rus;eng:Moses 2.1.1 / MosesCore Europarl...     NaN
# 2                             srclc:kor;eng:GT-KOR 1.0     NaN
# 3                             srclc:kor;eng:GT-KOR 1.0     NaN
# 4    srclc:ces;eng:Moses 2.1.1 / MosesCore Europarl...     NaN
# ..                                                 ...     ...
# 361  srclc:spa;eng:Moses 2.1.1 / MosesCore Europarl...     NaN
# 362  srclc:spa;eng:Moses 2.1.1 / MosesCore Europarl...     NaN
# 363  srclc:spa;eng:Moses 2.1.1 / MosesCore Europarl...     NaN
# 364                           srclc:por;eng:GT-POR 1.0     NaN
# 365                           srclc:por;eng:GT-POR 1.0     NaN
#
# [366 rows x 16 columns]

# %%
mentions = pd.read_csv("../../data/raw/20220707000000.mentions.csv", delimiter="\t", header=None, names=header_mentions, usecols=['ActionGeo_CountryCode']).squeeze()
mentions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3990/3298811547.py in <module>
# ----> 1 mentions = pd.read_csv("../../data/raw/20220707000000.mentions.csv", delimiter="\t", header=None, names=header_mentions, usecols=['ActionGeo_CountryCode']).squeeze()
#       2 mentions
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1751
#    1752         try:
# -> 1753             return mapping[engine](f, **self.options)
#    1754         except Exception:
#    1755             if self.handles is not None:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#     133                 self.orig_names
#     134             ):
# --> 135                 self._validate_usecols_names(usecols, self.orig_names)
#     136
#     137             # error: Cannot determine type of 'names'
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _validate_usecols_names(self, usecols, names)
#     915         missing = [c for c in usecols if c not in names]
#     916         if len(missing) > 0:
# --> 917             raise ValueError(
#     918                 f"Usecols do not match columns, columns expected but not found: "
#     919                 f"{missing}"
#
# ValueError: Usecols do not match columns, columns expected but not found: ['ActionGeo_CountryCode']

# %%
def check_language(start, end):
    for date in pd.date_range(start, end, freq='15T').to_pydatetime():
        str_date = date.strftime("%Y%m%d%H%M%S")
        mentions = pd.read_csv(f"../../data/raw/{str_date}.mentions.csv", delimiter="\t", header=None, names=header_mentions, usecols=['MentionDocTranslationInfo']).squeeze()
        not_na_count = mentions.notna().sum()
        # print(not_na_count)
        if not_na_count > 0:
            print(f"Pas d'anglais à cette date: {date}")

# %%
start = dt(2023, 1, 7)
end = dt(2023, 1, 8)
check_language(start, end)

# %%
gkg = pd.read_csv("../../data/raw/20230107003000.translation.gkg.csv", delimiter="\t", header=None, encoding = "ISO-8859-1", usecols=[25])
gkg
# Out:
#                                                     25
# 0    srclc:fra;eng:Moses 2.1.1 / MosesCore Europarl...
# 1    srclc:fra;eng:Moses 2.1.1 / MosesCore Europarl...
# 2    srclc:fra;eng:Moses 2.1.1 / MosesCore Europarl...
# 3    srclc:fra;eng:Moses 2.1.1 / MosesCore Europarl...
# 4    srclc:fra;eng:Moses 2.1.1 / MosesCore Europarl...
# ..                                                 ...
# 960                           srclc:vie;eng:GT-VIE 1.0
# 961                           srclc:vie;eng:GT-VIE 1.0
# 962                           srclc:vie;eng:GT-VIE 1.0
# 963                           srclc:vie;eng:GT-VIE 1.0
# 964                           srclc:slv;eng:GT-SLV 1.0
#
# [965 rows x 1 columns]

# %% [markdown]
# a) afficher le nombre d’articles/évènements qu’il y a eu pour chaque triplet (jour, pays de l’évènement, langue de l’article).

# %% [markdown]
# jour : Events[ Day, YearMonth, Year, DateAdd ] \
# pays : Events[ (GeoEvents) ] (the Geo_FeatureID column should be used) \
# langue : Mentions[ MentionDocTranslationInfo ]

# %% [markdown]
# lien event -> mention: GlobalEventID \
# lien mention -> gkg: mentionIdentifier -> DocumentIdentifier

# %% [markdown]
# Localisation:
# - Origine de l'actor
# - Lieu de l'actor au moment de l'évenement
# - Lieu de déroulement de l'action

# %% [markdown]
# Un acteur a donc un lieu d'origine fixe mais aussi un lieu associé à chaque évenement le concernant. Comment materialiser cela dans le graphe ?
# 1) Noeud Lieu pour les origines des actors et les évenements + caractérisation du lieu dans le lien acteur évenement\
# La redondance d'un noeud géographique et de propriété géographique dans des liens n'est elle pas dégueulasse ?
# 2) Pas de noeud lieu -> caractéristiques transferer dans les noeuds d'origines (origine devient une propriété d'actor ou event)

# %% [markdown]
# D'après les questions, il est préferable de garder un noeud lieu, la localisation des actors n'est pas très utiles pour y répondre

# %% [markdown]
# ### Person

# %% [markdown]
# Besoin de differencier les acteurs à un niveau plus fin -> q3 (filtrer les personnes qui ...) \
# Comment représenter ça dans Neo4j ? Heritage possible ? -> un noeud actor, comportant les propriété principales, associé à un noeud person ou organization etc
